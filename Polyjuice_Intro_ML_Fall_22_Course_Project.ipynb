# %% [markdown]
# Polyjuice - Intro ML Fall 22 Course Project

# %% [markdown]
# ## Background

# %% [markdown]
# Counterfactuals are conditional sentences that discuss what would have been true if conditions were different. Therefore, pertubations of counterfactuals are important for training and analysis of a variety of different NLP models as they are used to assess how a prediction changes when the original texts were changed slightly [1].
#
# Counterfactuals generation nowadays relies on human annotators or automatic text generators [2]. Out of the two methods, manual generation of counterfactual examples are costly and time-consuming and could bear human biases. At the same time, the existing automated generators are mostly not application agnostic, which results in ignoring subsets of perturbations that may be useful for other applications. Neither of the methods are ideal for diverse and efficient counterfactuals generation.
#
# Polyjuice, on the otherhand, is a counterfactual generator that is application agnostic, meaning that it will first generate a pool of general purpose counterfactual examples where users could choose from based on their use cases [3].
#
# Polyjuice is expected to produce counterfactual examples that are close to the original text, fluent in expression, robust for each application, and covers a large variety of use cases [4].

# %% [markdown]
# ## Working with the existing code

# %% [markdown]
# Source: https://github.com/tongshuangwu/polyjuice
#
# Below, we are cloning the repo from Polyjuice github and installing dependecies required.
#
# After the polyjuice package is imported, we used a sample prompt to feed into polyjuice to get counterfactual examples, which we used the perturb() function to achieve.
#
# We could also use perturb() function with more argument, including control code to pass in (ctrl_code=), number of counterfactual examples to gerneate(num_perturbations=). The control codes could be chosen from 'resemantic', 'restructure', 'negation', 'insert', 'lexical', 'shuffle', 'quantifier' and 'delete'.
#
# After the counterfactuals are generated, we could detect the control code of the generated text by calling detect_ctrl_code() on the original text and the generated text.
#
# We had to change the version of the dependencies to the minimum dependencies required since there was a transformer error because of version mismatch.
#
# We also had to import "nltk" package and download "omw-1.4" directly before importing Polyjuice to avoid an error raised by package not found.

# %%
# !pip install munch==2.5.0 spacy==3.0.6
# !pip install sentence-transformers==1.1.0 transformers==4.5.1
# !pip install pattern==3.6.0
# !pip install nltk scipy zss
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: munch==2.5.0 in /usr/local/lib/python3.8/dist-packages (2.5.0)
# Requirement already satisfied: spacy==3.0.6 in /usr/local/lib/python3.8/dist-packages (3.0.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from munch==2.5.0) (1.15.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (0.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (2.23.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (0.10.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (0.7.9)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (1.21.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (3.0.8)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (2.11.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (2.4.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (21.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (1.0.9)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (0.10.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (1.7.4)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (8.0.17)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (2.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from spacy==3.0.6) (3.0.10)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy==3.0.6) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy==3.0.6) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.6) (2022.9.24)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.4.0,>=0.3.0->spacy==3.0.6) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy==3.0.6) (2.0.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sentence-transformers==1.1.0 in /usr/local/lib/python3.8/dist-packages (1.1.0)
# Requirement already satisfied: transformers==4.5.1 in /usr/local/lib/python3.8/dist-packages (4.5.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (0.1.97)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (1.0.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (1.13.0+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from sentence-transformers==1.1.0) (3.7)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (0.10.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (0.0.53)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (3.8.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers==4.5.1) (2022.6.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->sentence-transformers==1.1.0) (4.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers==1.1.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->sentence-transformers==1.1.0) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->transformers==4.5.1) (3.0.9)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->transformers==4.5.1) (2022.9.24)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from sacremoses->transformers==4.5.1) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers==1.1.0) (3.1.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pattern==3.6.0 in /usr/local/lib/python3.8/dist-packages (3.6)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (18.8.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (0.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (4.6.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (1.7.3)
# Requirement already satisfied: backports.csv in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (1.0.7)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (20221105)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (2.23.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (6.0.10)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (4.9.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (3.7)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (0.8.11)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (1.21.6)
# Requirement already satisfied: mysqlclient in /usr/local/lib/python3.8/dist-packages (from pattern==3.6.0) (2.1.1)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern==3.6.0) (2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern==3.6.0) (9.0.0)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern==3.6.0) (3.8.0)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern==3.6.0) (9.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern==3.6.0) (3.1.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern==3.6.0) (3.5.2)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern==3.6.0) (1.15.0)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.8/dist-packages (from portend>=2.1.1->cherrypy->pattern==3.6.0) (5.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern==3.6.0) (2022.6)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.8/dist-packages (from feedparser->pattern==3.6.0) (1.0.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern==3.6.0) (3.2.3)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern==3.6.0) (3.11.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern==3.6.0) (2.2.2)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern==3.6.0) (4.2.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern==3.6.0) (5.10.0)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern==3.6.0) (2.1.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->jaraco.text->jaraco.collections->cherrypy->pattern==3.6.0) (3.11.0)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk->pattern==3.6.0) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->pattern==3.6.0) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk->pattern==3.6.0) (2022.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk->pattern==3.6.0) (4.64.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern==3.6.0) (38.0.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern==3.6.0) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern==3.6.0) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern==3.6.0) (2.21)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->pattern==3.6.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->pattern==3.6.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->pattern==3.6.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->pattern==3.6.0) (2022.9.24)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from zc.lockfile->cherrypy->pattern==3.6.0) (57.4.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (3.7)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (1.7.3)
# Requirement already satisfied: zss in /usr/local/lib/python3.8/dist-packages (1.2.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.8/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.8/dist-packages (from nltk) (2022.6.2)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.8/dist-packages (from scipy) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from zss) (1.15.0)

# %%
# !pip install polyjuice_nlp
# !pip install torch
# The SpaCy language package
# !python -m spacy download en_core_web_sm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting polyjuice_nlp
#   Downloading polyjuice_nlp-0.1.5-py3-none-any.whl (30 kB)
# Requirement already satisfied: transformers>=4.5.1 in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (4.5.1)
# Requirement already satisfied: munch>=2.5.0 in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (2.5.0)
# Requirement already satisfied: sentence-transformers>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (1.1.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (3.7)
# Requirement already satisfied: zss in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (1.2.0)
# Requirement already satisfied: spacy>=3.0.6 in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (3.0.6)
# Requirement already satisfied: pattern>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (3.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from polyjuice_nlp) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from munch>=2.5.0->polyjuice_nlp) (1.15.0)
# Requirement already satisfied: cherrypy in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (18.8.0)
# Requirement already satisfied: future in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (0.16.0)
# Requirement already satisfied: python-docx in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (0.8.11)
# Requirement already satisfied: backports.csv in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (1.0.7)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (6.0.10)
# Requirement already satisfied: mysqlclient in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (2.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (4.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (1.21.6)
# Requirement already satisfied: pdfminer.six in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (20221105)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pattern>=3.6.0->polyjuice_nlp) (4.9.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=1.1.0->polyjuice_nlp) (4.64.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=1.1.0->polyjuice_nlp) (1.13.0+cu116)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=1.1.0->polyjuice_nlp) (1.0.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.8/dist-packages (from sentence-transformers>=1.1.0->polyjuice_nlp) (0.1.97)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (8.0.17)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (0.7.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (3.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (2.0.7)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (1.7.4)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (2.4.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (2.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (0.10.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (57.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (21.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (2.11.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (0.3.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (0.10.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy>=3.0.6->polyjuice_nlp) (3.0.8)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy>=3.0.6->polyjuice_nlp) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy>=3.0.6->polyjuice_nlp) (5.2.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->pattern>=3.6.0->polyjuice_nlp) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->pattern>=3.6.0->polyjuice_nlp) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->pattern>=3.6.0->polyjuice_nlp) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->pattern>=3.6.0->polyjuice_nlp) (2022.9.24)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch>=1.6.0->sentence-transformers>=1.1.0->polyjuice_nlp) (4.4.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.8/dist-packages (from transformers>=4.5.1->polyjuice_nlp) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.5.1->polyjuice_nlp) (2022.6.2)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.8/dist-packages (from transformers>=4.5.1->polyjuice_nlp) (0.10.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from transformers>=4.5.1->polyjuice_nlp) (3.8.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.4.0,>=0.3.0->spacy>=3.0.6->polyjuice_nlp) (7.1.2)
# Requirement already satisfied: cheroot>=8.2.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern>=3.6.0->polyjuice_nlp) (9.0.0)
# Requirement already satisfied: portend>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.1.0)
# Requirement already satisfied: jaraco.collections in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.8.0)
# Requirement already satisfied: zc.lockfile in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern>=3.6.0->polyjuice_nlp) (2.0)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.8/dist-packages (from cherrypy->pattern>=3.6.0->polyjuice_nlp) (9.0.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.8/dist-packages (from cheroot>=8.2.1->cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.5.2)
# Requirement already satisfied: tempora>=1.8 in /usr/local/lib/python3.8/dist-packages (from portend>=2.1.1->cherrypy->pattern>=3.6.0->polyjuice_nlp) (5.1.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from tempora>=1.8->portend>=2.1.1->cherrypy->pattern>=3.6.0->polyjuice_nlp) (2022.6)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.8/dist-packages (from feedparser->pattern>=3.6.0->polyjuice_nlp) (1.0.0)
# Requirement already satisfied: jaraco.text in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.11.0)
# Requirement already satisfied: jaraco.classes in /usr/local/lib/python3.8/dist-packages (from jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.2.3)
# Requirement already satisfied: jaraco.context>=4.1 in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (4.2.0)
# Requirement already satisfied: autocommand in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (2.2.2)
# Requirement already satisfied: inflect in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (2.1.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from jaraco.text->jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (5.10.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.8/dist-packages (from importlib-resources->jaraco.text->jaraco.collections->cherrypy->pattern>=3.6.0->polyjuice_nlp) (3.11.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy>=3.0.6->polyjuice_nlp) (2.0.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.8/dist-packages (from nltk->polyjuice_nlp) (1.2.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern>=3.6.0->polyjuice_nlp) (38.0.4)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from pdfminer.six->pattern>=3.6.0->polyjuice_nlp) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.8/dist-packages (from cryptography>=36.0.0->pdfminer.six->pattern>=3.6.0->polyjuice_nlp) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.8/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->pattern>=3.6.0->polyjuice_nlp) (2.21)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn->sentence-transformers>=1.1.0->polyjuice_nlp) (3.1.0)
# Installing collected packages: polyjuice-nlp
# Successfully installed polyjuice-nlp-0.1.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.8/dist-packages (1.13.0+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from torch) (4.4.0)
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-sm==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl (13.7 MB)
#      |████████████████████████████████| 13.7 MB 27.6 MB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.64.1)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.21.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.17)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.10.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.10)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.8)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.23.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (21.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (57.4.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.7)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (5.2.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.24.3)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.1)
# Installing collected packages: en-core-web-sm
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.4.1
#     Uninstalling en-core-web-sm-3.4.1:
#       Successfully uninstalled en-core-web-sm-3.4.1
# Successfully installed en-core-web-sm-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import nltk
nltk.download('omw-1.4')
from polyjuice import Polyjuice

pj = Polyjuice(model_path="uw-hai/polyjuice", is_cuda=True)

# the base sentence
text = "It is great for kids."
perturbations = pj.perturb(text)
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# Downloading:   0%|          | 0.00/828 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/510M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/167 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
perturbations = pj.perturb(
    orig_sent=text,
    # can specify where to put the blank. Otherwise, it's automatically selected.
    # Can be a list or a single sentence.
    blanked_sent="It is [BLANK] for kids.",
    # can also specify the ctrl code (a list or a single code.)
    # The code should be from 'resemantic', 'restructure', 'negation', 'insert', 'lexical', 'shuffle', 'quantifier', 'delete'.
    ctrl_code="negation",
    # Customzie perplexity score. 
    perplex_thred=5,
    # number of perturbations to return
    num_perturbations=1,
    # the function also takes in additional arguments for huggingface generators.
    num_beams=3
)

# return: [
# 'It is not great for kids.', 
# 'It is great for kids but not for anyone.',
# 'It is great for kids but not for any adults.']

# %%
pj.detect_ctrl_code(
    "it's great for kids.", 
    "It is great for kids but not for any adults.")
# return: negation
# Out:
# 'negation'

# %% [markdown]
# ## Validating a claim

# %% [markdown]
# The claim we chose to validate is that the success rate of satisfactory counterfactuals generated by Polyjuice with a control code is much higher than those generated without a control code [5]. In the paper, the success rate increased from 5% to 47% by using control code "negation" to perturb the original prompts.
#
# We chose this claim to validate because of two reasons. The first reason is that the claim has clear process and results, making it possible to reproduce.
#
# The second reason is that the result from this claim is essential for arguing that Polyjuice performs significantly better than other existing text generators - in this case, we chose to compare it with GPT-2 fine-tuned without control code (Polyjuice -a).
#
# To validate the claim, we are following the method discussed in section A.2.2 of the paper.  We are using 100 prompts instead of 300 prompts [6] mentioned in the paper because the process of generating counterfactuals without control codes take longer time than the online notebook permit for a single section. Therefore, we decided to use 100 prompts, which is a large enough sample size to see a significant improvement on the result, but also small enough to be able to finish within the permitted time.
#
# We chose "negation" as the control code because it is said to produce one of the most significant improvement when control code is passed in [7].
#
# We chose to use the dataset from Stanford NLP because it is rated as one of the top sentiment analysis datasets for machine learning [8], and it has a relatively small file size in comparison to the others. Moreover, since it is adapted from movie reviews from rotten tomatoes, it is a good representation of naturally occuring sentences [9] that Polyjuice trains on.
#
# We start by importing the dataset zip file from Stanford NLP website, and unzip the file. And then we open the text file and choose the first 100 prompts as input for the models.
#
# We first train the GPT-2 finetuned without control code model, which is also called Polyjuice -a [10]. The code for perturb() and detect_control_code is adapted from https://github.com/tongshuangwu/polyjuice, but the rest of the logic was added by us. For example, the for loop to loop through the sentences in the input, the try-catch block to account for exceptions arise during perturbations, and calculating the success rate.
#
# The success rate is calculated by detecting the control code from the perturbed sentences, and compare it with the desired control code [11]. If at least one of the control codes from the perturbed sentences match the desired control code, the perturbation is deemed successful.
#
# After we get the success rate from Polyjuice -a, we use the same method to calculate success rate from Polyjuice. The only difference is this time when we call perturb(), we are passing in the control code argument "negation".
#
# After the success rates for both models are calculated, we calculate the difference between them to see the improvement.
#
# We could see significantly improvement in success rate when control code is passed in as an arguement. We ran the experiment multiple times and we got success rate for Polyjuice -a to be ~11%, and Polyjuice to be ~42%, which is a ~31% increase in success rate.
#
# One interesting find is that Polyjuice is not just more effective, it is also more efficient. We could see a big gap in execution time where Polyjuice -a takes almost 3x as much time as Polyjuice to generate conterfactuals.
#
# From the experiment results, we conclude that the success rate of generating satisfactory counterfactual examples increased significantly by using control code "negation" to perturb the original prompts.

# %%
# getting the dataset from Stanford NLP: https://nlp.stanford.edu/sentiment/code.html
from io import BytesIO
from urllib.request import urlopen
from zipfile import ZipFile
zipurl = 'http://nlp.stanford.edu/~socherr/stanfordSentimentTreebank.zip'
with urlopen(zipurl) as zipresp:
    with ZipFile(BytesIO(zipresp.read())) as zfile:
        zfile.extractall('/tmp')

# %%
# using the first 100 prompt from the dataset as input
nltk.download('punkt')
with open('/tmp/stanfordSentimentTreebank/original_rt_snippets.txt', 'r') as in_file:
    text = in_file.read()
    sents = nltk.sent_tokenize(text)

sents = sents[:100]
len(sents)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 100

# %%
desired_control_code = "negation"

# %%
# %%time

# Polyjuice -a (without control code)
success_num = 0
size=0

for text in sents:
  perturbations = []
  
  try:
    perturbations = pj.perturb(
      orig_sent=text,
      # number of perturbations to return
      num_perturbations=3,
      # the function also takes in additional arguments for huggingface generators.
      num_beams=5
    )
  except Exception as e:
      print(f"Could not produce counterfactuals for the sentence {text}, skipping to next sentence")
      print(e)
    
  if perturbations == []:
    size+=1
    continue

  control_codes = []
  for p in perturbations:
    control_codes.append(pj.detect_ctrl_code(text, p))

  for code in control_codes:
    if code == desired_control_code:
      success_num +=1
      break
  size+=1
success_rate = success_num/size
success_rate
# Out:
# CPU times: user 2h 12min 51s, sys: 2min 20s, total: 2h 15min 12s
# Wall time: 2h 14min 55s
# 0.11

# %%
# %%time

# polyjuice (with control code)
success_num = 0
size = 0

for text in sents:
  perturbations = []

  perturbations = pj.perturb(
        orig_sent=text,
        ctrl_code=desired_control_code,
        # number of perturbations to return
        num_perturbations=3,
        # the function also takes in additional arguments for huggingface generators.
        num_beams=5
  )

  control_codes = []
  for p in perturbations:
    control_codes.append(pj.detect_ctrl_code(text, p))

  for code in control_codes:
    if code == desired_control_code:
      success_num +=1
      break
  size+=1
success_rate_with_code = success_num/size
success_rate_with_code
# Out:
# CPU times: user 26min 34s, sys: 31.9 s, total: 27min 6s
# Wall time: 27min 3s
# 0.42

# %%
success_rate_increase = success_rate_with_code - success_rate
success_rate_increase
# Out:
# 0.31

# %% [markdown]
# ## References

# %% [markdown]
# [1] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6707. arXiv preprint arXiv:2101.00288 (2021).
#
# [2] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6707. arXiv preprint arXiv:2101.00288 (2021).
#
# [3] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6707-6708. arXiv preprint arXiv:2101.00288 (2021).
#
# [4] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6708. arXiv preprint arXiv:2101.00288 (2021).
#
# [5] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6710. arXiv preprint arXiv:2101.00288 (2021).
#
# [6] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6721. arXiv preprint arXiv:2101.00288 (2021).
#
# [7] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6721. arXiv preprint arXiv:2101.00288 (2021).
#
# [8] ---. Top 12 Free Sentiment Analysis Datasets | Classified and Labeled. 27 July 2021, www.repustate.com/blog/sentiment-analysis-datasets.
#
# [9] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6709. arXiv preprint arXiv:2101.00288 (2021).
#
# [10] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6721. arXiv preprint arXiv:2101.00288 (2021).
#
# [11] Wu, Tongshuang, et al. "Polyjuice: Generating counterfactuals for explaining, evaluating, and improving models." Pages 6721. arXiv preprint arXiv:2101.00288 (2021).
